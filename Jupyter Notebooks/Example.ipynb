# %%
import os
import netCDF4 as nc
#get the file path for loading, data file is under the same dir with the notebook
filename="20121015_00_ecmwf_ensemble_forecast.PRESSURE_LEVELS.EUR_LL10.120.pl.nc"
foldername="ECWMF Datasets"
filepath=os.path.join(os.path.dirname(os.getcwd()),foldername,filename)

# read the raw data and extract the needed data
# exrtact the value of Geopotential under the pressure of 500 hPA in the certain
Pressure_Levels_data = nc.Dataset(filepath,"r")

Pressure_Levels_data.variables
# Out:
# OrderedDict([('lat', <class 'netCDF4._netCDF4.Variable'>
#               float32 lat(lat)
#                   units: degrees_north
#               unlimited dimensions:
#               current shape = (41,)
#               filling on, default _FillValue of 9.969209968386869e+36 used),
#              ('lon', <class 'netCDF4._netCDF4.Variable'>
#               float32 lon(lon)
#                   units: degrees_east
#               unlimited dimensions:
#               current shape = (101,)
#               filling on, default _FillValue of 9.969209968386869e+36 used),
#              ('isobaric', <class 'netCDF4._netCDF4.Variable'>
#               float32 isobaric(isobaric)
#                   units: hPa
#                   long_name: Isobaric surface
#                   positive: down
#                   GRIB1_level_code: 100
#               unlimited dimensions:
#               current shape = (12,)
#               filling on, default _FillValue of 9.969209968386869e+36 used),
#              ('time', <class 'netCDF4._netCDF4.Variable'>
#               int32 time(time)
#                   units: Hour since 2012-10-15T00:00:00.000Z
#                   standard_name: time
#                   long_name: Uninitialized analysis / image product / forecast product valid for RT + P1
#               unlimited dimensions:
#               current shape = (1,)
#               filling on, default _FillValue of -2147483647 used),
#              ('ens0', <class 'netCDF4._netCDF4.Variable'>
#               int32 ens0(ens0)
#                   _CoordinateAxisType: Ensemble
#               unlimited dimensions:
#               current shape = (51,)
#               filling on, default _FillValue of -2147483647 used),
#              ('Geopotential_isobaric', <class 'netCDF4._netCDF4.Variable'>
#               float32 Geopotential_isobaric(time, ens0, isobaric, lat, lon)
#                   long_name: Geopotential @ Isobaric surface
#                   units: m2.s-2
#                   missing_value: nan
#                   grid_mapping: LatLon_Projection
#                   Grib_Variable_Id: VAR_98-0-128-129_L100
#                   Grib1_Center: 98
#                   Grib1_Subcenter: 0
#                   Grib1_TableVersion: 128
#                   Grib1_Parameter: 129
#                   Grib1_Parameter_Name: Z
#                   Grib1_Level_Type: 100
#               unlimited dimensions:
#               current shape = (1, 51, 12, 41, 101)
#               filling on, default _FillValue of 9.969209968386869e+36 used),
#              ('Temperature_isobaric', <class 'netCDF4._netCDF4.Variable'>
#               float32 Temperature_isobaric(time, ens0, isobaric, lat, lon)
#                   long_name: Temperature @ Isobaric surface
#                   units: K
#                   missing_value: nan
#                   grid_mapping: LatLon_Projection
#                   Grib_Variable_Id: VAR_98-0-128-130_L100
#                   Grib1_Center: 98
#                   Grib1_Subcenter: 0
#                   Grib1_TableVersion: 128
#                   Grib1_Parameter: 130
#                   Grib1_Parameter_Name: T
#                   Grib1_Level_Type: 100
#               unlimited dimensions:
#               current shape = (1, 51, 12, 41, 101)
#               filling on, default _FillValue of 9.969209968386869e+36 used),
#              ('U_velocity_isobaric', <class 'netCDF4._netCDF4.Variable'>
#               float32 U_velocity_isobaric(time, ens0, isobaric, lat, lon)
#                   long_name: U velocity @ Isobaric surface
#                   units: m.s-1
#                   missing_value: nan
#                   grid_mapping: LatLon_Projection
#                   Grib_Variable_Id: VAR_98-0-128-131_L100
#                   Grib1_Center: 98
#                   Grib1_Subcenter: 0
#                   Grib1_TableVersion: 128
#                   Grib1_Parameter: 131
#                   Grib1_Parameter_Name: U
#                   Grib1_Level_Type: 100
#               unlimited dimensions:
#               current shape = (1, 51, 12, 41, 101)
#               filling on, default _FillValue of 9.969209968386869e+36 used),
#              ('V_velocity_isobaric', <class 'netCDF4._netCDF4.Variable'>
#               float32 V_velocity_isobaric(time, ens0, isobaric, lat, lon)
#                   long_name: V velocity @ Isobaric surface
#                   units: m.s-1
#                   missing_value: nan
#                   grid_mapping: LatLon_Projection
#                   Grib_Variable_Id: VAR_98-0-128-132_L100
#                   Grib1_Center: 98
#                   Grib1_Subcenter: 0
#                   Grib1_TableVersion: 128
#                   Grib1_Parameter: 132
#                   Grib1_Parameter_Name: V
#                   Grib1_Level_Type: 100
#               unlimited dimensions:
#               current shape = (1, 51, 12, 41, 101)
#               filling on, default _FillValue of 9.969209968386869e+36 used),
#              ('Specific_humidity_isobaric', <class 'netCDF4._netCDF4.Variable'>
#               float32 Specific_humidity_isobaric(time, ens0, isobaric, lat, lon)
#                   long_name: Specific humidity @ Isobaric surface
#                   units: kg.kg-1
#                   missing_value: nan
#                   grid_mapping: LatLon_Projection
#                   Grib_Variable_Id: VAR_98-0-128-133_L100
#                   Grib1_Center: 98
#                   Grib1_Subcenter: 0
#                   Grib1_TableVersion: 128
#                   Grib1_Parameter: 133
#                   Grib1_Parameter_Name: Q
#                   Grib1_Level_Type: 100
#               unlimited dimensions:
#               current shape = (1, 51, 12, 41, 101)
#               filling on, default _FillValue of 9.969209968386869e+36 used)])
